# %%
import pandas as pd
import numpy as np
import string

# %%
df = pd.read_csv('./anno_all.csv')

# %%
df
# Out:
#       day                label  size  width  height                filename  \
# 0       6           holoclone1   896    136     126  1636967868_7966442.png
# 1       6          paraclone51   896     89      81  1636967868_7966442.png
# 2       6  paraclone_unknown30   896     36      43  1636967868_7966442.png
# 3       6           holoclone1   896    136     126    1636967871_39934.png
# 4       6           holoclone1   896    136     126   1636967873_944886.png
# ...   ...                  ...   ...    ...     ...                     ...
# 8475    6           paraclone9   896    109      82   1636977322_123213.png
# 8476    6  paraclone_unknown33   896     70      57   1636977322_123213.png
# 8477    6           paraclone9   896    109      82   1636977323_986122.png
# 8478    6  paraclone_unknown33   896     70      57   1636977323_986122.png
# 8479    6  paraclone_unknown33   896     70      57  1636977325_8510458.png
#
# ...

# %%
df['is_unknown'] = df['label'].apply(lambda x: 1 if len(x.split('_'))>1 else 0)
df['label'] = df['label'].apply(lambda x: x.replace('_unknown', ''))
# df['label'] = df['label'].apply(lambda x: x.strip(string.digits))

# %%
df_test = df[df['batch']==0]
# df_test = df[(df['batch']==0) | (df['batch']==1)]

# %%
df_train = df.drop(df_test.index)

# %%
df_test.to_csv('./test.csv', index=False, sep=',')

# %%
df_train.to_csv('./train.csv', index=False, sep=',')
