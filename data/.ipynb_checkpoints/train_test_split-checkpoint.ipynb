# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./anno_all.csv')

# %%
df
# Out:
#       day        label  size  width  height                filename  \
# 0       6   meroclone1  1344     81      80   1635559974_715148.png
# 1       6   meroclone2  1344    117     119   1635559974_715148.png
# 2       6  paraclone13  1344     49      49   1635559974_715148.png
# 3       6  paraclone14  1344     45      61   1635559974_715148.png
# 4       6   meroclone1  1344     81      80   1635559976_213709.png
# ...   ...          ...   ...    ...     ...                     ...
# 5464    6  paraclone24  1344    108     103   1635563657_019476.png
# 5465    6  paraclone24  1344    108     103   1635563658_988402.png
# 5466    6  paraclone24  1344    108     103  1635563661_0426219.png
# 5467    6  paraclone24  1344    108     103    1635563663_13599.png
# 5468    6  paraclone24  1344    108     103   1635563665_063637.png
#
#                     filename_gfp                filename_ph    x1    y1  ...  \
# 0      1635559974_715148_gfp.png   1635559974_715148_ph.png   793  1193  ...
# 1      1635559974_715148_gfp.png   1635559974_715148_ph.png    85  1198  ...
# 2      1635559974_715148_gfp.png   1635559974_715148_ph.png  1089   200  ...
# 3      1635559974_715148_gfp.png   1635559974_715148_ph.png   935     9  ...
# 4      1635559976_213709_gfp.png   1635559976_213709_ph.png  1204  1234  ...
# ...                          ...                        ...   ...   ...  ...
# 5464   1635563657_019476_gfp.png   1635563657_019476_ph.png   754   666  ...
# 5465   1635563658_988402_gfp.png   1635563658_988402_ph.png   496   520  ...
# 5466  1635563661_0426219_gfp.png  1635563661_0426219_ph.png   488   242  ...
# 5467    1635563663_13599_gfp.png    1635563663_13599_ph.png   173   666  ...
# 5468   1635563665_063637_gfp.png   1635563665_063637_ph.png   433   666  ...
#
#       ori_y1  ori_x2  ori_y2  clip_x1  clip_y1  clip_x2  clip_y2  batch  \
# 0       2734    2231    2814     1357     1541     2701     2885      2
# 1       2739    1559    2858     1357     1541     2701     2885      2
# 2       1741    2495    1790     1357     1541     2701     2885      2
# 3       1550    2337    1611     1357     1541     2701     2885      2
# 4       2734    2231    2814      946     1500     2290     2844      2
# ...      ...     ...     ...      ...      ...      ...      ...    ...
# 5464     666    4713     769     3851        0     5195     1344      9
# 5465     666    4713     769     4109      146     5453     1490      9
# 5466     666    4713     769     4117      424     5461     1768      9
# 5467     666    4713     769     4432        0     5776     1344      9
# 5468     666    4713     769     4172        0     5516     1344      9
#
#       bbox_idx  image_id
# 0            0         0
# 1            1         0
# 2            2         0
# 3            3         0
# 4            4         1
# ...        ...       ...
# 5464      5464      2565
# 5465      5465      2566
# 5466      5466      2567
# 5467      5467      2568
# 5468      5468      2569
#
# [5469 rows x 23 columns]

# %%
df_test = df[df['batch']==2]

# %%
df_train = df.drop(df_test.index)

# %%
df_test.to_csv('./test.csv', index=False, sep=',')

# %%
df_train.to_csv('./train.csv', index=False, sep=',')
