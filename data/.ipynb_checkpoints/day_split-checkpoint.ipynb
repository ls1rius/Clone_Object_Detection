# %%
import pandas as pd

# %%
mode = 'train'

# %%
df = pd.read_csv('./' + mode + '.csv')

# %%
day = 6

# %%
df_res = df[df['day']==day]

# %%
df_res
# Out:
#       day        label  size  width  height                filename  \
# 0       6   paraclone1  1344     59      67   1635560473_382136.png
# 1       6   paraclone1  1344     59      67   1635560474_871789.png
# 2       6   paraclone1  1344     59      67  1635560476_1412559.png
# 3       6   paraclone1  1344     59      67   1635560477_406445.png
# 4       6   paraclone1  1344     59      67   1635560478_853565.png
# ...   ...          ...   ...    ...     ...                     ...
# 4484    6  paraclone24  1344    108     103   1635563657_019476.png
# 4485    6  paraclone24  1344    108     103   1635563658_988402.png
# 4486    6  paraclone24  1344    108     103  1635563661_0426219.png
# 4487    6  paraclone24  1344    108     103    1635563663_13599.png
# 4488    6  paraclone24  1344    108     103   1635563665_063637.png
#
#                     filename_gfp                filename_ph    x1    y1  ...  \
# ...

# %%
df_res.to_csv('./' + mode + '_day' + str(day) + '.csv', index=False, sep=',')

# %%
df_res['width'].min()
# Out:
# 15

# %%
df_res['height'].min()
# Out:
# 23
